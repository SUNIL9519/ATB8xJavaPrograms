# %% [markdown]
# <a href="https://colab.research.google.com/github/SUNIL9519/ATB8xJavaPrograms/blob/master/Unified%20Python%20class%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 'Sunil'  # This is my name
print(a)
# Out:
# Sunil
